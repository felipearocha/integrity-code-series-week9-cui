# %% [markdown]
# # Week 9 — CUI Thermohygro-Electrochemical Simulation
# Run `python run_all.py` first to generate all assets.
# This notebook provides interactive exploration of individual modules.
